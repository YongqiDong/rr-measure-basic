# %%
import matplotlib.pyplot as plt
import numpy as np
from utils.gnn_data import *
# Out:
# 2023-11-22 15:55:24.699920: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-22 15:55:25.481373: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-11-22 15:55:25.481477: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-11-22 15:55:25.481484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
y1, y1_eye, errors_y1, errors_y1_eye = process_data(dataset_name='sum', level=1, tarnet=False)
y2, y2_eye, errors_y2, errors_y2_eye = process_data(dataset_name='sum', level=2, tarnet=False)
y3, y3_eye, errors_y3, errors_y3_eye = process_data(dataset_name='sum', level=3, tarnet=False)
y4, y4_eye, errors_y4, errors_y4_eye = process_data(dataset_name='sum', level=4, tarnet=False)
# Out:
# Data size: 16
# pehe eye: 4.816370818979811 +- 0.5204795854758921
# pehe: 3.290511761760012 +- 0.33426790574194754
# Kolmogorov-Smirnov test statistic: 0.28
# p-value: 0.0007377026282063397
# t-test statistic: 4.894538833569422
# p-value: 2.0389727238626693e-06
# Anderson-Darling test statistic: 11.229979416855963
# p-values: 0.001
#
# Data size: 32
# pehe eye: 2.280870971626478 +- 0.3482440209590703
# pehe: 1.9811495750793537 +- 0.2773694886725294
# Kolmogorov-Smirnov test statistic: 0.12
# p-value: 0.469506448503778
# t-test statistic: 1.335815897557219
# p-value: 0.18314283941269494
# Anderson-Darling test statistic: 0.4270929236414033
# p-values: 0.2220045889792558
#
# Data size: 64
# pehe eye: 0.5464835495749358 +- 0.10776324647863335
# pehe: 0.9112185242577567 +- 0.17551653911526482
# Kolmogorov-Smirnov test statistic: 0.31
# p-value: 0.00012016164291946694
# t-test statistic: -3.5138764865206764
# p-value: 0.0005471860179402795
# Anderson-Darling test statistic: 13.358414042442856
# p-values: 0.001
#
# Data size: 128
# pehe eye: 0.2572243594636846 +- 0.027133459369186368
# pehe: 0.4055257825152255 +- 0.03320790147627637
# Kolmogorov-Smirnov test statistic: 0.39
# p-value: 3.5690338557186834e-07
# t-test statistic: -6.8619076414392435
# p-value: 8.510112707593468e-11
# Anderson-Darling test statistic: 25.09259736258342
# p-values: 0.001
#
# Data size: 16
# pehe eye: 19.912740324367125 +- 3.0309870944035517
# pehe: 4.181379220453817 +- 0.6302068960385178
# Kolmogorov-Smirnov test statistic: 0.68
# p-value: 2.6207113475674983e-22
# t-test statistic: 10.082798024766438
# p-value: 1.4684649779576356e-19
# Anderson-Darling test statistic: 69.4837206226084
# p-values: 0.001
#
# Data size: 32
# pehe eye: 6.739679151148017 +- 1.2744427951900765
# pehe: 1.9649001501944656 +- 0.27570359061109695
# Kolmogorov-Smirnov test statistic: 0.5
# p-value: 1.0024645454361508e-11
# t-test statistic: 7.265914203761062
# p-value: 8.340091357854553e-12
# Anderson-Darling test statistic: 32.65318163025247
# p-values: 0.001
#
# Data size: 64
# pehe eye: 1.5094405746783786 +- 0.25087527243652447
# pehe: 1.485993300393513 +- 0.16820541536414865
# Kolmogorov-Smirnov test statistic: 0.15
# p-value: 0.21117008625127576
# t-test statistic: 0.15403137673084064
# p-value: 0.8777418784851805
# Anderson-Darling test statistic: 1.5527598904331668
# p-values: 0.0743161274663194
#
# Data size: 128
# pehe eye: 0.76812648681652 +- 0.09825032014533538
# pehe: 1.450530371072434 +- 0.1367685069414037
# Kolmogorov-Smirnov test statistic: 0.54
# p-value: 1.0245697148897385e-13
# t-test statistic: -8.04057494872708
# p-value: 7.987264931708783e-14
# Anderson-Darling test statistic: 40.408825083364206
# p-values: 0.001
#
# Data size: 16
# pehe eye: 91.10368916467341 +- 17.18853056101688
# pehe: 13.01705226541824 +- 4.751719943786492
# Kolmogorov-Smirnov test statistic: 0.81
# p-value: 3.93815390175582e-33
# t-test statistic: 8.688316558133803
# p-value: 1.3810710094808642e-15
# Anderson-Darling test statistic: 78.50538175447569
# p-values: 0.001
#
# Data size: 32
# pehe eye: 36.443171685767425 +- 8.301965177777575
# pehe: 6.650322369442373 +- 1.16745317611402
# Kolmogorov-Smirnov test statistic: 0.66
# p-value: 6.55317981883723e-21
# t-test statistic: 7.0512822915178175
# p-value: 2.8914837130932698e-11
# Anderson-Darling test statistic: 58.21324353385837
# p-values: 0.001
#
# Data size: 64
# pehe eye: 11.66212774807498 +- 2.641531158570247
# pehe: 6.109037642306703 +- 1.0071762010835437
# Kolmogorov-Smirnov test statistic: 0.3
# p-value: 0.0002248739317492479
# t-test statistic: 3.8975677438024254
# p-value: 0.00013292921605440408
# Anderson-Darling test statistic: 8.972011579667754
# p-values: 0.001
#
# Data size: 128
# pehe eye: 4.953652961436576 +- 0.9290650380500113
# pehe: 6.803157447298691 +- 1.0414392752903645
# Kolmogorov-Smirnov test statistic: 0.22
# p-value: 0.015577131622877688
# t-test statistic: -2.62952370170411
# p-value: 0.009222039336948195
# Anderson-Darling test statistic: 6.364153551847387
# p-values: 0.0011624661633833743
#
# Data size: 16
# pehe eye: 420.35996362364364 +- 76.96074903628747
# pehe: 59.07424838331499 +- 18.202576129557404
# Kolmogorov-Smirnov test statistic: 0.73
# p-value: 4.3321337732975196e-26
# t-test statistic: 9.064647399197035
# p-value: 1.229637754737546e-16
# Anderson-Darling test statistic: 69.96306455182153
# p-values: 0.001
#
# Data size: 32
# pehe eye: 199.0158763630521 +- 63.08853919220491
# pehe: 25.351222025678027 +- 5.751476162865479
# Kolmogorov-Smirnov test statistic: 0.66
# p-value: 6.55317981883723e-21
# t-test statistic: 5.439423203661423
# p-value: 1.565978250396436e-07
# Anderson-Darling test statistic: 62.605517575258915
# p-values: 0.001
#
# Data size: 64
# pehe eye: 76.47452214445059 +- 19.341104284855387
# pehe: 25.118896351709104 +- 5.485337745917055
# Kolmogorov-Smirnov test statistic: 0.41
# p-value: 6.617357604827955e-08
# t-test statistic: 5.068700427946741
# p-value: 9.164757646325848e-07
# Anderson-Darling test statistic: 26.288319711415568
# p-values: 0.001
#
# Data size: 128
# pehe eye: 33.64021134196824 +- 9.338005671340133
# pehe: 27.32919668415445 +- 5.424913526439277
# Kolmogorov-Smirnov test statistic: 0.14
# p-value: 0.2819416298082479
# t-test statistic: 1.159543009519825
# p-value: 0.24763130834007982
# Anderson-Darling test statistic: 0.6137445945006342
# p-values: 0.18457323042888507

# %%
y1_tarnet, errors_y1_tarnet = process_data(dataset_name='sum', level=1, tarnet=True)
y2_tarnet, errors_y2_tarnet = process_data(dataset_name='sum', level=2, tarnet=True)
y3_tarnet, errors_y3_tarnet = process_data(dataset_name='sum', level=3, tarnet=True)
y4_tarnet, errors_y4_tarnet = process_data(dataset_name='sum', level=4, tarnet=True)
# Out:
# Data size: 16
# pehe: 3.5946973893387275 +- 0.26478540448636684
# Data size: 32
# pehe: 3.295605763516088 +- 0.2268315700996306
# Data size: 64
# pehe: 3.651799284709648 +- 0.2536172375146587
# Data size: 128
# pehe: 1.1270079406802318 +- 0.2359396948398562
# Data size: 16
# pehe: 14.64835699131769 +- 1.6576123849797362
# Data size: 32
# pehe: 13.808580629818618 +- 1.412823905054202
# Data size: 64
# pehe: 12.234786102037447 +- 1.4124963842565965
# Data size: 128
# pehe: 1.9967144993054047 +- 0.30312615998646536
# Data size: 16
# pehe: 76.37133658613894 +- 12.171093553708944
# Data size: 32
# pehe: 63.020493717212084 +- 7.2503064399241905
# Data size: 64
# pehe: 49.76348581131511 +- 6.5309054735490255
# Data size: 128
# pehe: 8.572107214700502 +- 1.1612614812488395
# Data size: 16
# pehe: 333.5278498837942 +- 57.54457664493178
# Data size: 32
# pehe: 272.38045763136347 +- 44.72843607868231
# Data size: 64
# pehe: 197.4763450263191 +- 30.95628540962416
# Data size: 128
# pehe: 43.226662256796686 +- 8.030935277467039

# %%
y1

# %%
x = np.array([16, 32, 64, 128])

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot the first set of data with errors
axs[0, 0].errorbar(x, y1, yerr=errors_y1, capsize=5, label='GNN-TARnet(graph)')
axs[0, 0].errorbar(x, y1_eye, yerr=errors_y1_eye, capsize=5, label='GNN-TARnet(ident.)')
axs[0, 0].errorbar(x, y1_tarnet, yerr=errors_y1_tarnet, capsize=5, label='TARnet')

# axs[0, 0].set_yscale('log')
axs[0, 0].set_xticks(x)
axs[0, 0].set_title('1 layer')
axs[0, 0].set_xlabel('Num samples')
axs[0, 0].set_ylabel('Sqrt(PEHE)')

# Plot the second set of data with errors
axs[0, 1].errorbar(x, y2, yerr=errors_y2, capsize=5, label='GNN-TARnet(graph)')
axs[0, 1].errorbar(x, y2_eye, yerr=errors_y2_eye, capsize=5, label='GNN-TARnet(ident.)')
axs[0, 1].errorbar(x, y2_tarnet, yerr=errors_y2_tarnet, capsize=5, label='TARnet')

# axs[0, 1].set_yscale('log')
axs[0, 1].set_xticks(x)
axs[0, 1].set_title('2 layers')
axs[0, 1].set_xlabel('Num samples')
axs[0, 1].set_ylabel('Sqrt(PEHE)')

# Plot the third set of data with errors
axs[1, 0].errorbar(x, y3, yerr=errors_y3, capsize=5, label='GNN-TARnet(graph)')
axs[1, 0].errorbar(x, y3_eye, yerr=errors_y3_eye, capsize=5, label='GNN-TARnet(ident.)')
axs[1, 0].errorbar(x, y3_tarnet, yerr=errors_y3_tarnet, capsize=5, label='TARnet')


# axs[1, 0].set_yscale('log')
axs[1, 0].set_xticks(x)
axs[1, 0].set_title('3 layers')
axs[1, 0].set_xlabel('Num samples')
axs[1, 0].set_ylabel('Sqrt(PEHE)')

# Plot the fourth set of data with errors
axs[1, 1].errorbar(x, y4, yerr=errors_y4, capsize=5, label='GNN-TARnet(graph)')
axs[1, 1].errorbar(x, y4_eye, yerr=errors_y4_eye, capsize=5, label='GNN-TARnet(ident.)')
axs[1, 1].errorbar(x, y4_tarnet, yerr=errors_y4_tarnet, capsize=5, label='TARnet')



axs[1, 1].set_yscale('log')
axs[1, 1].set_xticks(x)
axs[1, 1].set_title('4 layers')
axs[1, 1].set_xlabel('Num samples')
axs[1, 1].set_ylabel('Sqrt(PEHE)')

# Add legend to each subplot
for ax in axs.flat:
    ax.legend()

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
